# %%
import pandas as pd
import csv

# %%
def allfridays(year):
    return pd.date_range(start=str(year), end=str(year+1), 
                         freq='W-FRI').strftime('%Y%m%d').tolist()

# %%
Vanderburgh_weekly_claims = pd.read_csv("vanderburgh_unemployment_claims.csv")

# %%
Vanderburgh_weekly_claims.head(14)
# Out:
#                  Geography  State Fips  County Fips  Year     Month  \
# 0   Vanderburgh County, IN          18          163  2020   January
# 1   Vanderburgh County, IN          18          163  2020   January
# 2   Vanderburgh County, IN          18          163  2020   January
# 3   Vanderburgh County, IN          18          163  2020   January
# 4   Vanderburgh County, IN          18          163  2020  February
# 5   Vanderburgh County, IN          18          163  2020  February
# 6   Vanderburgh County, IN          18          163  2020  February
# 7   Vanderburgh County, IN          18          163  2020  February
# 8   Vanderburgh County, IN          18          163  2020  February
# 9   Vanderburgh County, IN          18          163  2020     March
# 10  Vanderburgh County, IN          18          163  2020     March
# 11  Vanderburgh County, IN          18          163  2020     March
# 12  Vanderburgh County, IN          18          163  2020     March
# ...

# %%
Vanderburgh_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']

# %%
Vanderburgh_weekly_claims['Date'] = allfridays(2020)[:14]

# %%
Vanderburgh_weekly_claims['InitialClaims'] = Vanderburgh_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Vanderburgh_weekly_claims['InitialClaims'] = Vanderburgh_weekly_claims['InitialClaims'].astype(int)

# %%
Decatur_weekly_claims = pd.read_csv("decatur_unemployment_claims.csv")
Decatur_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Decatur_weekly_claims['Date'] = allfridays(2020)[:14]

# %%
Johnson_weekly_claims = pd.read_csv("johnson_unemployment_claims.csv")
Johnson_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Johnson_weekly_claims['Date'] = allfridays(2020)[:14]
Johnson_weekly_claims['InitialClaims'] = Johnson_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Johnson_weekly_claims['InitialClaims'] = Johnson_weekly_claims['InitialClaims'].astype(int)

# %%
Boone_weekly_claims = pd.read_csv("boone_unemployment_claims.csv")
Boone_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Boone_weekly_claims['Date'] = allfridays(2020)[:14]

# %%
Lake_weekly_claims = pd.read_csv("lake_unemployment_claims.csv")
Lake_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Lake_weekly_claims['Date'] = allfridays(2020)[:14]
Lake_weekly_claims['InitialClaims'] = Lake_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Lake_weekly_claims['InitialClaims'] = Lake_weekly_claims['InitialClaims'].astype(int)

# %%
Warrick_weekly_claims = pd.read_csv("warrick_unemployment_claims.csv")
Warrick_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Warrick_weekly_claims['Date'] = allfridays(2020)[:14]

# %%
Allen_weekly_claims = pd.read_csv("allen_unemployment_claims.csv")
Allen_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Allen_weekly_claims['Date'] = allfridays(2020)[:14]
Allen_weekly_claims['InitialClaims'] = Allen_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Allen_weekly_claims['InitialClaims'] = Allen_weekly_claims['InitialClaims'].astype(int)

Hamilton_weekly_claims = pd.read_csv("hamilton_unemployment_claims.csv")
Hamilton_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Hamilton_weekly_claims['Date'] = allfridays(2020)[:14]
Hamilton_weekly_claims['InitialClaims'] = Hamilton_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Hamilton_weekly_claims['InitialClaims'] = Hamilton_weekly_claims['InitialClaims'].astype(int)

Hendricks_weekly_claims = pd.read_csv("hendricks_unemployment_claims.csv")
Hendricks_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Hendricks_weekly_claims['Date'] = allfridays(2020)[:14]
Hendricks_weekly_claims['InitialClaims'] = Hendricks_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Hendricks_weekly_claims['InitialClaims'] = Hendricks_weekly_claims['InitialClaims'].astype(int)

Marion_weekly_claims = pd.read_csv("marion_unemployment_claims.csv")
Marion_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Marion_weekly_claims['Date'] = allfridays(2020)[:14]
Marion_weekly_claims['InitialClaims'] = Marion_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Marion_weekly_claims['InitialClaims'] = Marion_weekly_claims['InitialClaims'].astype(int)

Monroe_weekly_claims = pd.read_csv("monroe_unemployment_claims.csv")
Monroe_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
Monroe_weekly_claims['Date'] = allfridays(2020)[:14]
Monroe_weekly_claims['InitialClaims'] = Monroe_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
Monroe_weekly_claims['InitialClaims'] = Monroe_weekly_claims['InitialClaims'].astype(int)

StJoseph_weekly_claims = pd.read_csv("stjoseph_unemployment_claims.csv")
StJoseph_weekly_claims.columns = ['County','StateFips','CountyFips','Year', 'Month', 'MonthCode','Week', 'InitialClaims', 'ChangeFrom2019']
StJoseph_weekly_claims['Date'] = allfridays(2020)[:14]
StJoseph_weekly_claims['InitialClaims'] = StJoseph_weekly_claims['InitialClaims'].map(lambda x: x.replace(',', ''))
StJoseph_weekly_claims['InitialClaims'] = StJoseph_weekly_claims['InitialClaims'].astype(int)

# %%
StJoseph_weekly_claims.head(15)
# Out:
#                    County  StateFips  CountyFips  Year     Month  MonthCode  \
# 0   St. Joseph County, IN         18         141  2020   January          1
# 1   St. Joseph County, IN         18         141  2020   January          1
# 2   St. Joseph County, IN         18         141  2020   January          1
# 3   St. Joseph County, IN         18         141  2020   January          1
# 4   St. Joseph County, IN         18         141  2020  February          2
# 5   St. Joseph County, IN         18         141  2020  February          2
# 6   St. Joseph County, IN         18         141  2020  February          2
# 7   St. Joseph County, IN         18         141  2020  February          2
# 8   St. Joseph County, IN         18         141  2020  February          2
# 9   St. Joseph County, IN         18         141  2020     March          3
# 10  St. Joseph County, IN         18         141  2020     March          3
# ...

# %%
Decatur_Covid = pd.read_pickle('decatur_covid.pkl')
Johnson_Covid = pd.read_pickle('johnson_covid.pkl')
Vanderburgh_Covid = pd.read_pickle('vanderburgh_covid.pkl')
Boone_Covid = pd.read_pickle('Boone_covid.pkl')
Lake_Covid = pd.read_pickle('Lake_covid.pkl')
Warrick_Covid = pd.read_pickle('Warrick_covid.pkl')

Allen_Covid = pd.read_pickle('Allen_covid.pkl')
Hamilton_Covid = pd.read_pickle('Hamilton_covid.pkl')
Hendricks_Covid = pd.read_pickle('Hendricks_covid.pkl')
Marion_Covid = pd.read_pickle('Marion_covid.pkl')
Monroe_Covid = pd.read_pickle('Monroe_covid.pkl')
StJoseph_Covid = pd.read_pickle('StJoseph_covid.pkl')

# %%
StJoseph_Covid.head()
# Out:
#               County GEOGID      Date  Count
# 0  St. Joseph County  18141  20200306      0
# 1  St. Joseph County  18141  20200307      0
# 2  St. Joseph County  18141  20200308      0
# 3  St. Joseph County  18141  20200309      0
# 4  St. Joseph County  18141  20200310      0

# %%
Vanderburgh_Covid_Weekly_Claims = pd.merge(Vanderburgh_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Vanderburgh_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)

# %%
Johnson_Covid_Weekly_Claims = pd.merge(Johnson_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Johnson_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)

# %%
Decatur_Covid_Weekly_Claims = pd.merge(Decatur_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Decatur_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)

# %%
Boone_Covid_Weekly_Claims = pd.merge(Boone_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Boone_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)
Lake_Covid_Weekly_Claims = pd.merge(Lake_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Lake_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)
Warrick_Covid_Weekly_Claims = pd.merge(Warrick_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Warrick_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)

Allen_Covid_Weekly_Claims = pd.merge(Allen_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Allen_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)
Hamilton_Covid_Weekly_Claims = pd.merge(Hamilton_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Hamilton_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)
Hendricks_Covid_Weekly_Claims = pd.merge(Hendricks_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Hendricks_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)

Marion_Covid_Weekly_Claims = pd.merge(Marion_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Marion_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)
Monroe_Covid_Weekly_Claims = pd.merge(Monroe_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           Monroe_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)
StJoseph_Covid_Weekly_Claims = pd.merge(StJoseph_weekly_claims[['County', 'StateFips', 'CountyFips', 'InitialClaims', 'Date']], 
                                           StJoseph_Covid[['Count', 'Date']], how='outer', on='Date', sort=True)

# %%
Hendricks_Covid_Weekly_Claims.head(50)
# Out:
#                   County  StateFips  CountyFips  InitialClaims      Date  \
# 0   Hendricks County, IN       18.0        63.0           64.0  20200103
# 1   Hendricks County, IN       18.0        63.0           49.0  20200110
# 2   Hendricks County, IN       18.0        63.0           65.0  20200117
# 3   Hendricks County, IN       18.0        63.0           54.0  20200124
# 4   Hendricks County, IN       18.0        63.0           38.0  20200131
# 5   Hendricks County, IN       18.0        63.0           41.0  20200207
# 6   Hendricks County, IN       18.0        63.0           29.0  20200214
# 7   Hendricks County, IN       18.0        63.0           21.0  20200221
# 8   Hendricks County, IN       18.0        63.0           25.0  20200228
# 9   Hendricks County, IN       18.0        63.0           35.0  20200306
# 10                   NaN        NaN         NaN            NaN  20200307
# 11                   NaN        NaN         NaN            NaN  20200308
# ...

# %%
Vanderburgh_Covid_Weekly_Claims['County'] = 'Vanderburgh County, IN'
Vanderburgh_Covid_Weekly_Claims['StateFips'] = '18.0'
Vanderburgh_Covid_Weekly_Claims['CountyFips'] = '163.0'
Vanderburgh_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Decatur_Covid_Weekly_Claims['County'] = 'Decatur County, IN'
Decatur_Covid_Weekly_Claims['StateFips'] = '18.0'
Decatur_Covid_Weekly_Claims['CountyFips'] = '31.0'
Decatur_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Johnson_Covid_Weekly_Claims['County'] = 'Johnson County, IN'
Johnson_Covid_Weekly_Claims['StateFips'] = '18.0'
Johnson_Covid_Weekly_Claims['CountyFips'] = '81.0'
Johnson_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Boone_Covid_Weekly_Claims['County'] = 'Boone County, IN'
Boone_Covid_Weekly_Claims['StateFips'] = '18.0'
Boone_Covid_Weekly_Claims['CountyFips'] = '11.0'
Boone_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Lake_Covid_Weekly_Claims['County'] = 'Lake County, IN'
Lake_Covid_Weekly_Claims['StateFips'] = '18.0'
Lake_Covid_Weekly_Claims['CountyFips'] = '89.0'
Lake_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Warrick_Covid_Weekly_Claims['County'] = 'Warrick County, IN'
Warrick_Covid_Weekly_Claims['StateFips'] = '18.0'
Warrick_Covid_Weekly_Claims['CountyFips'] = '173.0'
Warrick_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Allen_Covid_Weekly_Claims['County'] = 'Allen County, IN'
Allen_Covid_Weekly_Claims['StateFips'] = '18.0'
Allen_Covid_Weekly_Claims['CountyFips'] = '3.0'
Allen_Covid_Weekly_Claims.fillna(0, inplace=True)

Hamilton_Covid_Weekly_Claims['County'] = 'Hamilton County, IN'
Hamilton_Covid_Weekly_Claims['StateFips'] = '18.0'
Hamilton_Covid_Weekly_Claims['CountyFips'] = '57.0'
Hamilton_Covid_Weekly_Claims.fillna(0, inplace=True)

Hendricks_Covid_Weekly_Claims['County'] = 'Hendricks County, IN'
Hendricks_Covid_Weekly_Claims['StateFips'] = '18.0'
Hendricks_Covid_Weekly_Claims['CountyFips'] = '63.0'
Hendricks_Covid_Weekly_Claims.fillna(0, inplace=True)

Marion_Covid_Weekly_Claims['County'] = 'Marion County, IN'
Marion_Covid_Weekly_Claims['StateFips'] = '18.0'
Marion_Covid_Weekly_Claims['CountyFips'] = '97.0'
Marion_Covid_Weekly_Claims.fillna(0, inplace=True)

Monroe_Covid_Weekly_Claims['County'] = 'Monroe County, IN'
Monroe_Covid_Weekly_Claims['StateFips'] = '18.0'
Monroe_Covid_Weekly_Claims['CountyFips'] = '105.0'
Monroe_Covid_Weekly_Claims.fillna(0, inplace=True)

StJoseph_Covid_Weekly_Claims['County'] = 'St. Joseph County, IN'
StJoseph_Covid_Weekly_Claims['StateFips'] = '18.0'
StJoseph_Covid_Weekly_Claims['CountyFips'] = '141.0'
StJoseph_Covid_Weekly_Claims.fillna(0, inplace=True)

# %%
Vanderburgh_Covid_Weekly_Claims.dtypes

# %%
Hendricks_Covid_Weekly_Claims.head(50)
# Out:
#                   County StateFips CountyFips  InitialClaims      Date  Count
# 0   Hendricks County, IN      18.0       63.0             64  20200103    0.0
# 1   Hendricks County, IN      18.0       63.0             49  20200110    0.0
# 2   Hendricks County, IN      18.0       63.0             65  20200117    0.0
# 3   Hendricks County, IN      18.0       63.0             54  20200124    0.0
# 4   Hendricks County, IN      18.0       63.0             38  20200131    0.0
# 5   Hendricks County, IN      18.0       63.0             41  20200207    0.0
# 6   Hendricks County, IN      18.0       63.0             29  20200214    0.0
# 7   Hendricks County, IN      18.0       63.0             21  20200221    0.0
# 8   Hendricks County, IN      18.0       63.0             25  20200228    0.0
# 9   Hendricks County, IN      18.0       63.0             35  20200306    0.0
# 10  Hendricks County, IN      18.0       63.0             25  20200313    0.0
# ...

# %%
Vanderburgh_Covid_Weekly_Claims.to_json('static/data/vanderburgh_covid_weekly_claims.json')

# %%
Johnson_Covid_Weekly_Claims.to_json('static/data/johnson_covid_weekly_claims.json')

# %%
Decatur_Covid_Weekly_Claims.to_json('static/data/decatur_covid_weekly_claims.json')

# %%
Boone_Covid_Weekly_Claims.to_json('static/data/boone_covid_weekly_claims.json')
Lake_Covid_Weekly_Claims.to_json('static/data/lake_covid_weekly_claims.json')
Warrick_Covid_Weekly_Claims.to_json('static/data/warrick_covid_weekly_claims.json')

# %%
Allen_Covid_Weekly_Claims.to_json('static/data/Allen_Covid_Weekly_Claims.json')
Hamilton_Covid_Weekly_Claims.to_json('static/data/Hamilton_Covid_Weekly_Claims.json')
Hendricks_Covid_Weekly_Claims.to_json('static/data/Hendricks_Covid_Weekly_Claims.json')

Marion_Covid_Weekly_Claims.to_json('static/data/Marion_Covid_Weekly_Claims.json')
Monroe_Covid_Weekly_Claims.to_json('static/data/Monroe_Covid_Weekly_Claims.json')
StJoseph_Covid_Weekly_Claims.to_json('static/data/StJoseph_Covid_Weekly_Claims.json')
