# %%
import bls 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from blsconnect import RequestBLS

# %%
from config import BLS_API_KEY
bls = RequestBLS(key=BLS_API_KEY)

Boone_Co_unemployment_monthly_stats = pd.DataFrame(bls.series(['LAUCN180110000000003','LAUCN180110000000004','LAUCN180110000000005','LAUCN180110000000006'], 2006, 2008))

# %%
Boone_Co_unemployment_monthly_stats
# Out:
#     year period periodName  LAUCN180110000000003  LAUCN180110000000004  \
# 0   2006    M01    January                   4.3                  1191
# 1   2006    M02   February                   4.6                  1262
# 2   2006    M03      March                   4.3                  1190
# 3   2006    M04      April                   3.6                  1010
# 4   2006    M05        May                   3.7                  1037
# 5   2006    M06       June                   3.7                  1051
# 6   2006    M07       July                   3.7                  1045
# 7   2006    M08     August                   3.6                  1004
# 8   2006    M09  September                   3.5                   977
# 9   2006    M10    October                   3.1                   883
# 10  2006    M11   November                   3.3                   948
# 11  2006    M12   December                   3.5                   983
# 12  2007    M01    January                   4.3                  1189
# 13  2007    M02   February                   4.2                  1174
# 14  2007    M03      March                   3.7                  1038
# 15  2007    M04      April                   3.4                   942
# 16  2007    M05        May                   3.1                   870
# 17  2007    M06       June                   3.3                   920
# 18  2007    M07       July                   3.1                   863
# 19  2007    M08     August                   3.2                   899
# 20  2007    M09  September                   3.1                   854
# 21  2007    M10    October                   3.0                   845
# 22  2007    M11   November                   3.4                   946
# 23  2007    M12   December                   3.7                  1040
# 24  2008    M01    January                   4.3                  1205
# 25  2008    M02   February                   4.3                  1209
# 26  2008    M03      March                   4.3                  1207
# 27  2008    M04      April                   3.4                   954
# 28  2008    M05        May                   3.8                  1070
# 29  2008    M06       June                   4.1                  1184
# 30  2008    M07       July                   4.1                  1198
# 31  2008    M08     August                   4.4                  1258
# 32  2008    M09  September                   4.0                  1143
# 33  2008    M10    October                   4.4                  1253
# 34  2008    M11   November                   5.0                  1422
# 35  2008    M12   December                   5.9                  1683
#
#     LAUCN180110000000005  LAUCN180110000000006
# 0                  26361                 27552
# 1                  26417                 27679
# 2                  26531                 27721
# 3                  26749                 27759
# 4                  27101                 28138
# 5                  27322                 28373
# 6                  27354                 28399
# 7                  27212                 28216
# 8                  26983                 27960
# 9                  27308                 28191
# 10                 27351                 28299
# 11                 27239                 28222
# 12                 26660                 27849
# 13                 26532                 27706
# 14                 26765                 27803
# 15                 26828                 27770
# 16                 27052                 27922
# 17                 27268                 28188
# 18                 27261                 28124
# 19                 27045                 27944
# 20                 27014                 27868
# 21                 27159                 28004
# 22                 27269                 28215
# 23                 27090                 28130
# 24                 26877                 28082
# 25                 26844                 28053
# 26                 27009                 28216
# 27                 27242                 28196
# 28                 27454                 28524
# 29                 27580                 28764
# 30                 27769                 28967
# 31                 27488                 28746
# 32                 27207                 28350
# 33                 27285                 28538
# 34                 26996                 28418
# 35                 26614                 28297

# %%
#Renamed the column names
Boone_Co_unemployment_monthly_stats.columns = ['year','period','periodName','Unemployment Rate', 'Unemployed', 'Employed','Labor Force']

# %%
#Boone_Co_unemployment_monthly_stats.index.names = ['Date']
#Boone_Co_unemployment_monthly_stats.index.names
Boone_Co_unemployment_monthly_stats
# Out:
#     year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0   2006    M01    January                4.3        1191     26361
# 1   2006    M02   February                4.6        1262     26417
# 2   2006    M03      March                4.3        1190     26531
# 3   2006    M04      April                3.6        1010     26749
# 4   2006    M05        May                3.7        1037     27101
# 5   2006    M06       June                3.7        1051     27322
# 6   2006    M07       July                3.7        1045     27354
# 7   2006    M08     August                3.6        1004     27212
# 8   2006    M09  September                3.5         977     26983
# 9   2006    M10    October                3.1         883     27308
# 10  2006    M11   November                3.3         948     27351
# 11  2006    M12   December                3.5         983     27239
# 12  2007    M01    January                4.3        1189     26660
# 13  2007    M02   February                4.2        1174     26532
# 14  2007    M03      March                3.7        1038     26765
# 15  2007    M04      April                3.4         942     26828
# 16  2007    M05        May                3.1         870     27052
# 17  2007    M06       June                3.3         920     27268
# 18  2007    M07       July                3.1         863     27261
# 19  2007    M08     August                3.2         899     27045
# 20  2007    M09  September                3.1         854     27014
# 21  2007    M10    October                3.0         845     27159
# 22  2007    M11   November                3.4         946     27269
# 23  2007    M12   December                3.7        1040     27090
# 24  2008    M01    January                4.3        1205     26877
# 25  2008    M02   February                4.3        1209     26844
# 26  2008    M03      March                4.3        1207     27009
# 27  2008    M04      April                3.4         954     27242
# 28  2008    M05        May                3.8        1070     27454
# 29  2008    M06       June                4.1        1184     27580
# 30  2008    M07       July                4.1        1198     27769
# 31  2008    M08     August                4.4        1258     27488
# 32  2008    M09  September                4.0        1143     27207
# 33  2008    M10    October                4.4        1253     27285
# 34  2008    M11   November                5.0        1422     26996
# 35  2008    M12   December                5.9        1683     26614
#
#     Labor Force
# 0         27552
# 1         27679
# 2         27721
# 3         27759
# 4         28138
# 5         28373
# 6         28399
# 7         28216
# 8         27960
# 9         28191
# 10        28299
# 11        28222
# 12        27849
# 13        27706
# 14        27803
# 15        27770
# 16        27922
# 17        28188
# 18        28124
# 19        27944
# 20        27868
# 21        28004
# 22        28215
# 23        28130
# 24        28082
# 25        28053
# 26        28216
# 27        28196
# 28        28524
# 29        28764
# 30        28967
# 31        28746
# 32        28350
# 33        28538
# 34        28418
# 35        28297

# %%
new_df_Boone = Boone_Co_unemployment_monthly_stats
# Create Year-Month by adding columns year and periodName
new_df_Boone['Year-Month'] = new_df_Boone["year"].astype(str) + "-" + new_df_Boone["periodName"] 
new_df_Boone['County'] = 'Boone'

new_df_Boone.head()
new_df_Boone.to_html("BooneData.html")

# %%
x_axis = new_df_Boone["periodName"]
y_axis = new_df_Boone["Unemployed"]
tick_locations = [value for value in x_axis]                   
qp11 = plt.bar(x_axis, y_axis, align="center", width =.7)

plt.xticks(tick_locations, new_df_Boone["Unemployed"] , rotation = 'vertical')
plt.xlabel('Year',  fontsize=20)
plt.ylabel('Unemployed',  fontsize=20)
plt.title("2017 Gender Averages", fontsize=20)
plt.legend( qp11,x_axis,loc='upper center', fancybox=True, shadow=True, bbox_to_anchor=(1.30, 1.0))
plt.savefig('Umemployment2008.png', bbox_inches = 'tight')
plt.show()

# %%
Lake_Co_unemployment_monthly_stats = pd.DataFrame(bls.series(['LAUCN180890000000003','LAUCN180890000000004','LAUCN180890000000005','LAUCN180890000000006'], 2006, 2008))

# %%
Lake_Co_unemployment_monthly_stats.head()
# Out:
#    year period periodName  LAUCN180890000000003  LAUCN180890000000004  \
# 0  2006    M01    January                   5.9                 13224
# 1  2006    M02   February                   6.4                 14394
# 2  2006    M03      March                   6.7                 15264
# 3  2006    M04      April                   5.8                 12991
# 4  2006    M05        May                   6.2                 14106
#
#    LAUCN180890000000005  LAUCN180890000000006
# 0                210763                223987
# 1                211264                225658
# 2                211726                226990
# 3                212547                225538
# 4                214249                228355

# %%
Lake_Co_unemployment_monthly_stats.columns = ['year','period','periodName','Unemployment Rate', 'Unemployed', 'Employed','Labor Force']
Lake_Co_unemployment_monthly_stats.head()
# Out:
#    year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0  2006    M01    January                5.9       13224    210763
# 1  2006    M02   February                6.4       14394    211264
# 2  2006    M03      March                6.7       15264    211726
# 3  2006    M04      April                5.8       12991    212547
# 4  2006    M05        May                6.2       14106    214249
#
#    Labor Force
# 0       223987
# 1       225658
# 2       226990
# 3       225538
# 4       228355

# %%
new_df_Lake = Lake_Co_unemployment_monthly_stats

new_df_Lake['Year-Month'] = new_df_Lake["year"].astype(str) + "-" + new_df_Lake["periodName"] 
new_df_Lake['County'] = 'Lake'

new_df_Lake.head()
# Out:
#    year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0  2006    M01    January                5.9       13224    210763
# 1  2006    M02   February                6.4       14394    211264
# 2  2006    M03      March                6.7       15264    211726
# 3  2006    M04      April                5.8       12991    212547
# 4  2006    M05        May                6.2       14106    214249
#
#    Labor Force     Year-Month County
# 0       223987   2006-January   Lake
# 1       225658  2006-February   Lake
# 2       226990     2006-March   Lake
# 3       225538     2006-April   Lake
# 4       228355       2006-May   Lake

# %%
Warrick_Co_unemployment_monthly_stats = pd.DataFrame(bls.series(['LAUCN181730000000003','LAUCN181730000000004','LAUCN181730000000005','LAUCN181730000000006'], 2008, 2019))
Warrick_Co_unemployment_monthly_stats.head()
# Out:
#    year period periodName  LAUCN181730000000003  LAUCN181730000000004  \
# 0  2008    M01    January                   4.3                  1313
# 1  2008    M02   February                   4.4                  1350
# 2  2008    M03      March                   4.3                  1318
# 3  2008    M04      April                   3.8                  1175
# 4  2008    M05        May                   4.3                  1324
#
#    LAUCN181730000000005  LAUCN181730000000006
# 0                 29438                 30751
# 1                 29273                 30623
# 2                 29441                 30759
# 3                 29700                 30875
# 4                 29756                 31080

# %%
Warrick_Co_unemployment_monthly_stats.columns = ['year','period','periodName','Unemployment Rate', 'Unemployed', 'Employed','Labor Force']
Warrick_Co_unemployment_monthly_stats.head()
# Out:
#    year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0  2008    M01    January                4.3        1313     29438
# 1  2008    M02   February                4.4        1350     29273
# 2  2008    M03      March                4.3        1318     29441
# 3  2008    M04      April                3.8        1175     29700
# 4  2008    M05        May                4.3        1324     29756
#
#    Labor Force
# 0        30751
# 1        30623
# 2        30759
# 3        30875
# 4        31080

# %%
new_df_Warrick = Warrick_Co_unemployment_monthly_stats

new_df_Warrick['Year-Month'] = new_df_Warrick["year"].astype(str) + "-" + new_df_Warrick["periodName"] 
new_df_Warrick['County'] = 'Warrick'

new_df_Warrick.head()
# Out:
#    year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0  2008    M01    January                4.3        1313     29438
# 1  2008    M02   February                4.4        1350     29273
# 2  2008    M03      March                4.3        1318     29441
# 3  2008    M04      April                3.8        1175     29700
# 4  2008    M05        May                4.3        1324     29756
#
#    Labor Force     Year-Month   County
# 0        30751   2008-January  Warrick
# 1        30623  2008-February  Warrick
# 2        30759     2008-March  Warrick
# 3        30875     2008-April  Warrick
# 4        31080       2008-May  Warrick

# %%
new_df_Warrick.to_html("WarrickData.html")
new_df_Warrick.to_json("WarrickData.json")

# %%
#new_df_Lake.to_html("LakeData.html")

# %%
new_df_Lake.to_json("LakeData.json")

# %%
new_df_Boone.to_html("BooneData.html")
new_df_Boone.to_json("BooneData.json")

# %%
from sqlalchemy import create_engine
#Create sqlite Engine
db = create_engine('sqlite:///project2.sqlite')

# %%
# Move the Warrick county data to UnemploymentData Table
new_df_Warrick.to_sql('CountyUnemploymentData', con=db, if_exists='append')
new_df_Warrick = pd.read_sql_query('SELECT * FROM CountyUnemploymentData',db)
new_df_Warrick.head()
# Out:
#    index  year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0      0  2008    M01    January                4.3        1313     29438
# 1      1  2008    M02   February                4.4        1350     29273
# 2      2  2008    M03      March                4.3        1318     29441
# 3      3  2008    M04      April                3.8        1175     29700
# 4      4  2008    M05        May                4.3        1324     29756
#
#    Labor Force     Year-Month   County
# 0        30751   2008-January  Warrick
# 1        30623  2008-February  Warrick
# 2        30759     2008-March  Warrick
# 3        30875     2008-April  Warrick
# 4        31080       2008-May  Warrick

# %%
#check the total number or rows in CountyUnemploymentData Table
new_df_Warrick_count = pd.read_sql_query('SELECT count(*) FROM CountyUnemploymentData',db)
new_df_Warrick_count
# Out:
#    count(*)
# 0       144

# %%
# Move the Lake county data to UnemploymentData Table

new_df_Lake.to_sql('CountyUnemploymentData', con=db, if_exists='append')
new_df_County = pd.read_sql_query('SELECT * FROM CountyUnemploymentData',db)
new_df_County.head()
# Out:
#    index  year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0      0  2008    M01    January                4.3        1313     29438
# 1      1  2008    M02   February                4.4        1350     29273
# 2      2  2008    M03      March                4.3        1318     29441
# 3      3  2008    M04      April                3.8        1175     29700
# 4      4  2008    M05        May                4.3        1324     29756
#
#    Labor Force     Year-Month   County
# 0        30751   2008-January  Warrick
# 1        30623  2008-February  Warrick
# 2        30759     2008-March  Warrick
# 3        30875     2008-April  Warrick
# 4        31080       2008-May  Warrick

# %%
#check the total number or rows in CountyUnemploymentData table
new_df_Lake_count = pd.read_sql_query('SELECT count(*) FROM CountyUnemploymentData',db)
new_df_Lake_count
# Out:
#    count(*)
# 0       180

# %%
# Move the Boone County data to CountyUnemploymentData Table
new_df_Boone.to_sql('CountyUnemploymentData', con=db, if_exists='append')
new_df_Boone = pd.read_sql_query('SELECT * FROM CountyUnemploymentData',db)
new_df_Boone.head()
# Out:
#    index  year period periodName  Unemployment Rate  Unemployed  Employed  \
# 0      0  2008    M01    January                4.3        1313     29438
# 1      1  2008    M02   February                4.4        1350     29273
# 2      2  2008    M03      March                4.3        1318     29441
# 3      3  2008    M04      April                3.8        1175     29700
# 4      4  2008    M05        May                4.3        1324     29756
#
#    Labor Force     Year-Month   County
# 0        30751   2008-January  Warrick
# 1        30623  2008-February  Warrick
# 2        30759     2008-March  Warrick
# 3        30875     2008-April  Warrick
# 4        31080       2008-May  Warrick

# %%
#check the total number or rows in CountyUnemploymentData Table
new_df_Boone_count = pd.read_sql_query('SELECT count(*) FROM CountyUnemploymentData',db)
new_df_Boone_count
# Out:
#    count(*)
# 0       216
